# %%
import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('C:\ProgramData\Anaconda3\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path ='./ajinkya/face' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
# Out:
# Face not found
# Collecting Samples Complete

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
print(cv2.__version__)
# Get the training data we previously made
data_path = r'C:\Users\ajink\Face-Recognition-App\ajinkya'
# a=listdir('d:/faces')
# print(a)
# """
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + "\\" + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    type(images)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)
# 
# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)
ajinkya_model=cv2.face.LBPHFaceRecognizer_create()
# Initialize facial recognizer
# model = cv2.
# model=cv2.f
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()

# Let's train our model 
ajinkya_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained sucessefully")
# Out:
# 4.2.0
# Model trained sucessefully

# %%
import cv2
import numpy as np
import webbrowser
import os

face_classifier = cv2.CascadeClassifier('C:\ProgramData\Anaconda3\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = ajinkya_model.predict(face)
        print(results)
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is Ajinkya'
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence > 70:
            cv2.putText(image, "Hey Ajinkya", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
           # cv2.putText(image, confidence, (450, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
                       
        else:
            cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
           # cv2.putText(image, confidence, (450, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# (12, 62.98880818879627)
# (99, 63.686676570488416)
# (32, 44.90627234304226)
# (26, 39.59605576401822)
# (26, 39.59605576401822)
# (88, 34.60188217536859)
# (22, 32.9256225390056)
# (22, 31.780360014355583)
# (22, 31.780360014355583)
# (22, 30.953030159578617)
# (22, 30.90998495184694)
# (22, 30.90998495184694)
# (22, 31.760501857929572)
# (22, 34.32243789441003)
# (22, 34.32243789441003)
# (32, 32.68892739467625)
# (32, 30.322205798387497)
# (22, 30.629986344275338)
# (22, 30.629986344275338)
# (22, 29.76920503623094)
# (53, 29.828333948346597)
# (53, 29.828333948346597)
# (4, 30.99742238189611)
# (32, 37.63673230892143)
# (99, 44.87889153762662)
# (99, 50.801168219591816)
# (99, 50.801168219591816)
# (99, 46.86211032776345)
# (99, 46.86211032776345)
# (99, 44.02166339627347)
# (99, 38.92792425743064)
# (99, 38.92792425743064)
# (99, 35.996097713132734)
# (32, 33.1981191592926)
# (32, 34.330491562017734)
# (32, 34.330491562017734)
# (32, 33.962790797209365)
# (85, 34.54827136464466)
# (4, 32.96928040047172)
# (22, 34.28067149155178)
# (22, 34.28067149155178)
# (99, 33.91599416292226)
# (22, 32.514452960861064)
# (22, 32.514452960861064)
# (32, 33.60265785335159)
# (22, 33.10001974992519)
# (99, 32.56893506993425)
# (99, 32.56893506993425)
# (32, 32.12751657130186)
# (4, 31.790612034708122)
# (32, 32.69904747095624)
# (32, 32.69904747095624)
# (32, 33.4580389009921)
# (32, 32.050573604837716)
# (32, 31.372713279246735)
# (32, 31.372713279246735)
# (85, 30.377837637727865)
# (32, 31.438856469249906)
# (32, 31.438856469249906)
# (8, 31.841636343591926)
# (57, 30.730275530237503)
# (26, 30.691905317214164)
# (26, 31.690461860777297)
# (26, 31.690461860777297)
# (26, 31.695210091105828)
# (4, 30.943772187899256)
# (26, 32.4992073738804)
# (26, 32.4992073738804)
# (32, 33.070307821223906)
# (99, 32.14336979881839)
# (99, 32.68103256256801)
# (99, 32.68103256256801)
# (32, 32.53643695068289)
# (85, 30.945565130145614)
# (99, 32.65934090102607)
# (99, 32.65934090102607)
# (99, 32.02447313312115)
# (99, 32.993109188503944)
# (26, 32.020676237341796)
# (26, 32.020676237341796)
# (32, 30.992523229802423)
# (32, 32.02952140750178)
# (99, 31.33889044486478)
# (26, 32.06344668763501)
# (99, 31.834812204968546)
# (26, 31.748961470434136)
# (26, 31.98095886775651)
# (26, 32.074920512008525)
# (26, 32.074920512008525)
# (26, 31.441856804498286)
# (73, 31.34922114198714)
# (4, 32.610413986952224)
# (4, 31.51290912861519)
# (88, 31.20193345754942)
# (88, 31.20193345754942)
# (26, 31.284870797447965)
# (85, 33.17288863266195)
# (26, 31.66779186738141)
# (26, 31.657609722015373)
# (99, 34.87815579443825)
# (32, 33.495909834200795)
# (32, 32.896694995837585)
# (32, 37.32622406382099)
# (32, 37.32622406382099)
# (32, 44.94000577009094)
# (26, 46.4228142709121)
# (87, 47.48545588225216)
# (83, 57.90688886065209)
# (83, 57.90688886065209)
# (26, 58.2870757493201)
# (26, 56.534814926287055)
# (99, 47.10500619338947)
# (99, 47.10500619338947)
# (2, 41.794765310318425)
# (99, 36.62675731903636)
# (2, 34.42196198378857)
# (2, 34.42196198378857)
# (7, 33.21799206360195)
# (5, 33.70543185887054)
# (5, 33.04685991036378)
# (5, 33.04685991036378)
# (8, 33.72820773983639)
# (29, 34.33117284779737)
# (29, 33.61441070799122)
# (29, 33.61441070799122)
# (73, 35.47755107409051)
# (99, 34.8447263375387)
# (32, 36.088250170539965)
# (32, 36.088250170539965)
# (2, 37.526428871520096)
# (99, 37.02879464269598)
# (32, 38.38815454500689)
# (32, 38.38815454500689)
# (32, 48.93195811220119)
# (32, 46.64746357486044)
# (32, 46.64746357486044)
# (86, 47.441984821716254)
# (83, 46.01967525881612)
# (32, 43.98302615715306)
# (32, 43.98302615715306)
# (32, 48.86497392478722)
# (99, 51.04158900245943)
# (99, 51.04158900245943)
# (99, 45.44031502362529)
# (32, 44.970762494738565)
# (32, 44.970762494738565)
# (32, 45.01511646229132)
# (83, 45.51503513138419)
# (32, 46.747114057999)
# (32, 46.747114057999)
# (87, 45.77684250777914)
# (99, 44.27344576873511)
# (32, 46.03344841093088)
# (32, 46.03344841093088)
# (32, 45.957200196274876)
# (83, 47.77247597529545)
# (32, 45.053835586097634)
# (32, 45.053835586097634)
# (84, 46.36638870369531)
# (32, 44.55108761130513)
# (32, 44.55108761130513)
# (86, 44.60207506108882)
# (32, 44.030175376006824)
# (32, 46.11603174653125)
# (32, 46.11603174653125)
# (32, 45.10955709294288)
# (32, 43.599323898863865)
# (32, 43.599323898863865)
# (32, 44.17832312009512)
# (32, 44.55774926914238)
# (32, 45.32698894842454)
# (26, 46.16347352335723)
# (26, 46.16347352335723)
# (26, 45.60145665947654)
# (26, 44.97875645232906)
# (83, 44.609083314183934)
# (83, 44.609083314183934)
# (4, 44.35950935498542)
# (32, 44.6358615595986)
# (32, 44.176338267130795)
# (99, 45.62755447942916)
# (99, 45.62755447942916)
# (32, 44.57856528962701)
# (32, 44.55650808704085)
# (32, 44.12507970016951)
# (32, 43.08764035159113)
# (32, 43.08764035159113)
# (26, 44.816879375178715)
# (26, 44.56976634494324)
# (99, 44.773127084624925)
# (32, 44.854277525404406)
# (32, 44.854277525404406)
# (32, 44.0204439373345)
# (32, 44.367553395269425)
# (32, 44.367553395269425)
# (32, 46.67904689003433)
# (32, 45.58485563713178)
# (32, 44.05744953758686)
# (32, 45.19857463423346)
# (32, 45.418941627511145)
# (32, 45.418941627511145)
# (32, 42.3569683181796)
# (26, 44.52165993511698)
# (32, 45.3379901323727)
# (32, 45.3379901323727)
# (4, 44.61950894863817)
# (32, 44.994168728473035)
# (26, 45.2911017184529)
# (26, 45.2911017184529)
# (99, 43.76270887530406)
# (26, 43.63993826150839)
# (83, 43.803390832449736)
# (99, 47.96536998836551)
# (99, 47.96536998836551)
# (26, 45.512005884221686)
# (22, 48.77489149141257)
# (32, 46.17692679136108)
# (32, 46.17692679136108)
